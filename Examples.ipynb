# %% [markdown]
# # A collection of twelve quantum circuits implemented and simulated using the QSiM.

# %% [markdown]
# ### Circuit 1

# %%
circuit = Circuit712(3)
circuit.measure_all()

circuit.draw_circuit()
# Out:
# q0:   |0>-------M--
#
# q1:   |0>-------M--
#
# q2:   |0>-------M--

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 1000, '001': 0, '010': 0, '011': 0, '100': 0, '101': 0, '110': 0, '111': 0 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[1.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 2

# %%
circuit = Circuit712(3)
circuit.h(0)
circuit.h(2)
circuit.measure(0)
circuit.measure(1)
circuit.measure(2)

circuit.draw_circuit()
# Out:
# q0:   |0>-------H-----M(0)--------
#
# q1:   |0>----------------M(1)-----
#
# q2:   |0>----------H--------M(2)--

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 221, '001': 272, '010': 0, '011': 0, '100': 243, '101': 264, '110': 0, '111': 0 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.25+0.j]
#  [0.25+0.j]
#  [0.  +0.j]
#  [0.  +0.j]
#  [0.25+0.j]
#  [0.25+0.j]
#  [0.  +0.j]
#  [0.  +0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 3

# %%
circuit = Circuit712(3)
circuit.h_all()
circuit.measure_all()
circuit.draw_circuit()
# Out:
# q0:   |0>--------H--M--
#
# q1:   |0>-------H--M--
#
# q2:   |0>--------H--M--

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 108, '001': 123, '010': 112, '011': 123, '100': 142, '101': 121, '110': 137, '111': 134 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 4

# %%
circuit = Circuit712(1000)
circuit.x(0)
circuit.x(2)
circuit.cnot(0, 1)
circuit.cnot(1, 2)
circuit.measure_all()
circuit.draw_circuit()
# Out:
# q0:   |0>-------X-----O-----M--
#                       |
# q1:   |0>-------------X--O--M--
#                          |
# q2:   |0>----------X-----X--M--

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 0, '001': 0, '010': 0, '011': 1000, '100': 0, '101': 0, '110': 0, '111': 0 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [1.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 5

# %%
circuit = Circuit712(1000)
circuit.x(0)
circuit.swap(0, 2)
circuit.measure_all()
circuit.draw_circuit()
# Out:
# q0:   |0>-------X--X--M--
#                    |
# q1:   |0>----------|--M--
#                    |
# q2:   |0>----------X--M--

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 0, '001': 0, '010': 0, '011': 0, '100': 1000, '101': 0, '110': 0, '111': 0 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [1.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 6

# %%
circuit = Circuit712(3)
circuit.h(0)
circuit.id(1)
circuit.s(0)
circuit.s(1)
circuit.h(0)
circuit.cnot(0, 1)
circuit.cnot(1, 0)
circuit.h(1)
circuit.measure_all()
circuit.draw_circuit()
# Out:
# q0:   |0>-------H------S-----H--O--X-----M--
#                                 |  |
# q1:   |0>----------id-----S-----X--O--H--M--
#
# q2:   |0>--------------------------------M--

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 525, '001': 0, '010': 475, '011': 0, '100': 0, '101': 0, '110': 0, '111': 0 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.5+0.j]
#  [0. +0.j]
#  [0.5+0.j]
#  [0. +0.j]
#  [0. +0.j]
#  [0. +0.j]
#  [0. +0.j]
#  [0. +0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 7

# %%
circuit = Circuit712(3)
for j in range(10):
    circuit.h(0)
    circuit.y(1)
    circuit.z(2)
circuit.measure(2)
circuit.measure(0)
circuit.measure(1)
circuit.draw_circuit()
# Out:
# q0:   |0>-------H--------H--------H--------H--------H--------H--------H--------H--------H--------H-----------M(1)-----
#
# q1:   |0>----------Y--------Y--------Y--------Y--------Y--------Y--------Y--------Y--------Y--------Y-----------M(2)--
#
# q2:   |0>-------------Z--------Z--------Z--------Z--------Z--------Z--------Z--------Z--------Z--------Z--M(0)--------

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 1000, '001': 0, '010': 0, '011': 0, '100': 0, '101': 0, '110': 0, '111': 0 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[1.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 8(Without Measurement)

# %%
circuit = Circuit712(3)
circuit.x(0)
circuit.x(1)
circuit.x(2)
circuit.h(0)
circuit.crz(1, 0, math.pi / 2)
circuit.crz(2, 0, math.pi / 4)
circuit.h(1)
circuit.crz(2, 1, math.pi / 2)
circuit.h(2)
circuit.swap(0, 2)
circuit.draw_circuit()
# Out:
# q0:   |0>-------X--------H--Z--R(π/2)--Z--R(π/4)-------------------X--
#                             |          |                           |
# q1:   |0>----------X--------O----------|----------H--Z--R(π/2)-----|--
#                                        |             |             |
# q2:   |0>-------------X----------------O-------------O----------H--X--

# %%
#(Without Measurement)
circuit.simulate(1000)
#circuit.simulation_result

# %%
### Circuit 8(With Measurement)

# %%
circuit = Circuit712(3)
circuit.x(0)
circuit.x(1)
circuit.x(2)
circuit.h(0)
circuit.crz(1, 0, math.pi / 2)
circuit.crz(2, 0, math.pi / 4)
circuit.h(1)
circuit.crz(2, 1, math.pi / 2)
circuit.h(2)
circuit.swap(0, 2)
circuit.measure_all()
circuit.draw_circuit()
# Out:
# q0:   |0>-------X--------H--Z--R(π/2)--Z--R(π/4)-------------------X--M--
#                             |          |                           |
# q1:   |0>----------X--------O----------|----------H--Z--R(π/2)-----|--M--
#                                        |             |             |
# q2:   |0>-------------X----------------O-------------O----------H--X--M--

# %%
#(With Measurement)
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 150, '001': 110, '010': 119, '011': 127, '100': 110, '101': 122, '110': 123, '111': 139 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]
#  [0.125+0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 9

# %%
circuit = Circuit712(3)
circuit.h(0)
circuit.x(1)
circuit.cs(0, 1)
circuit.measure(0)
circuit.measure(1)
circuit.draw_circuit()
# Out:
# q0:   |0>-------H-----O--M(0)-----
#                       |
# q1:   |0>----------X--S-----M(1)--
#
# q2:   |0>----------------------

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'00': 0, '01': 0, '10': 524, '11': 476 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0. +0.j]
#  [0. +0.j]
#  [0.5+0.j]
#  [0.5+0.j]
#  [0. +0.j]
#  [0. +0.j]
#  [0. +0.j]
#  [0. +0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# ### Circuit 10

# %%
circuit = Circuit712(3)
circuit.h(0)
circuit.h(1)
circuit.s(1)
circuit.h(1)
circuit.cx(0, 1)
circuit.h(1)
circuit.s(1)
circuit.h(0)
circuit.h(1)
circuit.x(0)
circuit.x(1)
circuit.h(1)
circuit.cx(0, 1)
circuit.h(1)
circuit.x(0)
circuit.x(1)
circuit.h(0)
circuit.h(1)
circuit.measure(0)
circuit.measure(1)



circuit.draw_circuit()
# Out:
# q0:   |0>-------H-----------O--------H-----X--------O-----X-----H-----M(0)-----
#                             |                       |
# q1:   |0>----------H--S--H--X--H--S-----H-----X--H--X--H-----X-----H-----M(1)--
#
# q2:   |0>-------------------------------------------------------------------

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'00': 0, '01': 0, '10': 1000, '11': 0 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.+0.j]
#  [0.+0.j]
#  [1.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]
#  [0.+0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# # Circuit 11

# %%
circuit = Circuit712(3)
circuit.h(0)
circuit.h(1)
circuit.ch(0,1)
circuit.measure_all()


circuit.draw_circuit()
# Out:
# q0:   |0>-------H-----O--M--
#                       |
# q1:   |0>----------H--H--M--
#
# q2:   |0>----------------M--

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 226, '001': 509, '010': 265, '011': 0, '100': 0, '101': 0, '110': 0, '111': 0 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.25+0.j]
#  [0.5 +0.j]
#  [0.25+0.j]
#  [0.  +0.j]
#  [0.  +0.j]
#  [0.  +0.j]
#  [0.  +0.j]
#  [0.  +0.j]]

# %%
circuit.draw_histogram()

# %% [markdown]
# # Circuit 12

# %%
circuit = Circuit712(3)
circuit.x(0)
circuit.sqrt_not(1)
circuit.x(1)
circuit.t_adjoint(2)
circuit.rx(2, np.pi / 8)
circuit.x(2)
circuit.swap(0, 1)
circuit.s_adjoint(0)
circuit.t(1)
circuit.crz(1,2, np.pi / 2)
circuit.sqrt_not(2)
circuit.h(0)
circuit.rz(0, np.pi / 2)
circuit.h(0)
circuit.ry(0, np.pi / 3)
circuit.t_adjoint(1)
circuit.rz(1, np.pi / 2)
circuit.swap(0, 2)
circuit.measure_all()
circuit.draw_circuit()
# Out:
# q0:   |0>-------X---------------------------X--S†----------------------H--RZ(π/2)--H--RY(π/3)---------------X--M--
#                                             |                                                               |
# q1:   |0>----------√NOT--X------------------X------T--O----------------------------------------T†--RZ(π/2)--|--M--
#                                                       |                                                     |
# q2:   |0>-------------------T†--RX(π/8)--X------------Z--R(π/2)--√NOT---------------------------------------X--M--

# %%
circuit.simulate(1000)
#circuit.simulation_result
# Out:
# {'000': 0, '001': 0, '010': 14, '011': 44, '100': 0, '101': 0, '110': 306, '111': 636 }

# %%
circuit.simulation_pre_measurement_statevector()
# Out:
#  The Pre-Measurement Statevector:
#   [[0.        +0.j]
#  [0.        +0.j]
#  [0.02062904+0.j]
#  [0.04622545+0.j]
#  [0.        +0.j]
#  [0.        +0.j]
#  [0.28793724+0.j]
#  [0.64520828+0.j]]

# %%
circuit.draw_histogram()
